# %% [markdown]
# <a href="https://colab.research.google.com/github/hws2002/Master-Python-with-Just-One-Book-ADP/blob/main/Chapter2/Data_Handling_6_merging_tables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()
iris = pd.DataFrame(iris.data, columns = iris.feature_names)
iris['class'] = load_iris()['target']

# %%
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      class
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 145      2
# 146      2
# 147      2
# 148      2
# 149      2
#
# [150 rows x 5 columns]

# %% [markdown]
# # 1. 결합

# %% [markdown]
# ## 1-1. 열 방향 결합

# %%
import pandas as pd
HR1 = pd.DataFrame({'이름' : ['장화', '홍련'],
                    '부서' : ['영업', '회계'],
                    '직급' : ['팀장', '사원']})
HR2 = pd.DataFrame({'이름' : ['콩쥐', '팥쥐'],
                    '부서' : ['영업', '인사'],
                    '직급' : ['사원', '팀장']})
pd.concat([HR1,HR2], axis = 0)
# Out:
#    이름  부서  직급
# 0  장화  영업  팀장
# 1  홍련  회계  사원
# 0  콩쥐  영업  사원
# 1  팥쥐  인사  팀장

# %%
pd.concat([HR1,HR2], axis = 0, ignore_index = True)
# Out:
#    이름  부서  직급
# 0  장화  영업  팀장
# 1  홍련  회계  사원
# 2  콩쥐  영업  사원
# 3  팥쥐  인사  팀장

# %%
HR3 = pd.DataFrame({'이름' : ['콩쥐', '팥쥐'],
                    '부서' : ['영업', '인사'],
                    '급여' : [3500, 2800]})
pd.concat([HR1,HR3], axis = 0, ignore_index = True)
# Out:
#    이름  부서   직급      급여
# 0  장화  영업   팀장     NaN
# 1  홍련  회계   사원     NaN
# 2  콩쥐  영업  NaN  3500.0
# 3  팥쥐  인사  NaN  2800.0

# %% [markdown]
# ## 1-2. 행 방향 결합

# %%
HR4 = pd.Series({1:2500}, name = '급여')
pd.concat([HR1,HR4], axis = 1)
# Out:
#    이름  부서  직급      급여
# 0  장화  영업  팀장     NaN
# 1  홍련  회계  사원  2500.0

# %%
HR5 = pd.DataFrame({'급여' : [4500, 3000, 3500]})
pd.concat([HR1,HR5], axis = 1)
# Out:
#     이름   부서   직급    급여
# 0   장화   영업   팀장  4500
# 1   홍련   회계   사원  3000
# 2  NaN  NaN  NaN  3500

# %% [markdown]
# # 2. 조인

# %% [markdown]
# ## 2-1. inner join

# %%
product = pd.DataFrame({'상품코드' : ['G1', 'G2', 'G3', 'G4'],
                        '상품명' : ['우유', '감자', '빵', '치킨']})
sale = pd.DataFrame({'주문번호' : [1001, 1002, 1002, 1003, 1004],
                     '상품코드' : ['G4', 'G3', 'G1', 'G3', 'G5'],
                     '주문수량' : [1, 4, 2, 2, 3]})
product
# Out:
#   상품코드 상품명
# 0   G1  우유
# 1   G2  감자
# 2   G3   빵
# 3   G4  치킨

# %%
sale
# Out:
#    주문번호 상품코드  주문수량
# 0  1001   G4     1
# 1  1002   G3     4
# 2  1002   G1     2
# 3  1003   G3     2
# 4  1004   G5     3

# %%
sale.merge(product, on = '상품코드', how = 'inner')
# Out:
#    주문번호 상품코드  주문수량 상품명
# 0  1001   G4     1  치킨
# 1  1002   G3     4   빵
# 2  1002   G1     2  우유
# 3  1003   G3     2   빵

# %% [markdown]
# # 2-2. Outer join

# %%
sale.merge(product, on = '상품코드',how = 'outer',sort = True)
# Out:
#      주문번호 상품코드  주문수량  상품명
# 0  1002.0   G1   2.0   우유
# 1     NaN   G2   NaN   감자
# 2  1002.0   G3   4.0    빵
# 3  1003.0   G3   2.0    빵
# 4  1001.0   G4   1.0   치킨
# 5  1004.0   G5   3.0  NaN

# %% [markdown]
# # 2-3. Right outer join

# %%
sale.merge(product, on ='상품코드', how = 'left')
# Out:
#    주문번호 상품코드  주문수량  상품명
# 0  1001   G4     1   치킨
# 1  1002   G3     4    빵
# 2  1002   G1     2   우유
# 3  1003   G3     2    빵
# 4  1004   G5     3  NaN

# %%
# 혹은
sale.merge(product, left_on = '상품코드', right_on = '상품코드', how = 'left',sort = True)
# Out:
#    주문번호 상품코드  주문수량  상품명
# 0  1002   G1     2   우유
# 1  1002   G3     4    빵
# 2  1003   G3     2    빵
# 3  1001   G4     1   치킨
# 4  1004   G5     3  NaN
