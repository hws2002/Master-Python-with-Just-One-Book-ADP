# %% [markdown]
# <a href="https://colab.research.google.com/github/hws2002/Master-Python-with-Just-One-Book-ADP/blob/main/Chapter2/Data_Handling_9_apply.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
score = {'학년' : [1,1,1,1,2,2],
         '반' : ['A','A','B','B','C','C'],
         '성별' : ['여자', '남자', '여자', '남자', '여자', '남자'],
         '성적' : [76, 88, 85, 72, 68, 70]
}
score = pd.DataFrame(score)
score
# Out:
#    학년  반  성별  성적
# 0   1  A  여자  76
# 1   1  A  남자  88
# 2   1  B  여자  85
# 3   1  B  남자  72
# 4   2  C  여자  68
# 5   2  C  남자  70

# %%
score = score.pivot_table(index = ['학년', '반'], columns = ['성별'], values = '성적')
score
# Out:
# 성별      남자    여자
# 학년 반
# 1  A  88.0  76.0
#    B  72.0  85.0
# 2  C  70.0  68.0

# %%
score.reset_index().melt(id_vars = ['학년', '반'], var_name = '성별', value_name = '성적')
# Out:
#    학년  반  성별    성적
# 0   1  A  남자  88.0
# 1   1  B  남자  72.0
# 2   2  C  남자  70.0
# 3   1  A  여자  76.0
# 4   1  B  여자  85.0
# 5   2  C  여자  68.0

# %% [markdown]
# # 1. Apply

# %%
import numpy as np
score.apply(np.sqrt, axis = 0)
# Out:
# 성별          남자        여자
# 학년 반
# 1  A  9.380832  8.717798
#    B  8.485281  9.219544
# 2  C  8.366600  8.246211

# %%
score.apply(np.max, axis = 0)
# Out:
# 성별
# 남자    88.0
# 여자    85.0
# dtype: float64

# %%
def plus_five(val):
  return val + 5
score.apply(plus_five)
# Out:
# 성별      남자    여자
# 학년 반
# 1  A  93.0  81.0
#    B  77.0  90.0
# 2  C  75.0  73.0

# %%
def class_avg(df):
  return np.ceil((df['남자'] + df['여자'])/2)
score.apply(class_avg, axis = 1)
# Out:
# 학년  반
# 1   A    82.0
#     B    79.0
# 2   C    69.0
# dtype: float64

# %% [markdown]
# # 2. Map

# %%
score['남자'].map(lambda x: x+5)
# Out:
# 학년  반
# 1   A    93.0
#     B    77.0
# 2   C    75.0
# Name: 남자, dtype: float64
