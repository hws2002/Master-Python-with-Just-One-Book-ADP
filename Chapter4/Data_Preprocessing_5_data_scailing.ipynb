# %% [markdown]
# <a href="https://colab.research.google.com/github/hws2002/Master-Python-with-Just-One-Book-ADP/blob/main/Chapter4/Data_Preprocessing_5_data_scailing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
iris_load = load_iris()
iris = pd.DataFrame(iris_load.data, columns = iris_load.feature_names)

iris['Class'] = iris_load.target
iris['Class'] = iris['Class'].map({0:'Setosa',1:'Versicolor',2:'Virginica'})
X_train, X_test, y_train, y_test = train_test_split(iris.drop(columns = ['Class']), iris['Class'],
                                                    test_size=0.2, random_state = 1004, stratify = iris['Class'])

print('X_train.shape : ', X_train.shape)
print('y_train.shape : ', y_train.shape)
# Out:
# X_train.shape :  (120, 4)
# y_train.shape :  (120,)

# %% [markdown]
# # 1. Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
StdScaler = StandardScaler()

StdScaler.fit(X_train)
X_train_std = StdScaler.transform(X_train)
X_test_std = StdScaler.transform(X_test)

print("\t\t(min,max)  (mean,std)")
print("Train_scaled (%.2f, %.2f) (%.2f, %.2f)"%(X_train_std.min(),
                                                X_train_std.max(),
                                                X_train_std.mean(),
                                                X_train_std.std()))
print("Test_scaled (%.2f, %.2f) (%.2f, %.2f)"%(X_test_std.min(),
                                                X_test_std.max(),
                                                X_test_std.mean(),
                                                X_test_std.std()))
# Out:
# 		(min,max)  (mean,std)
# Train_scaled (-2.37, 3.04) (0.00, 1.00)
# Test_scaled (-1.76, 2.48) (-0.01, 0.97)

# %% [markdown]
# # 2. Min-max Scaler

# %%
from sklearn.preprocessing import MinMaxScaler
MmScaler = MinMaxScaler()

MmScaler.fit(X_train)
X_train_Mm = MmScaler.transform(X_train)

X_test_Mm = MmScaler.transform(X_test)

print("\t\t(min, max), (mean, std)")
print("Train scaled (%.2f, %.2f) (%.2f, %.2f)"% (X_train_Mm.min(),
                                                 X_train_Mm.max(),
                                                 X_train_Mm.mean(),
                                                 X_train_Mm.std()))

print("Train scaled (%.2f, %.2f) (%.2f, %.2f)"% (X_test_Mm.min(),
                                                 X_test_Mm.max(),
                                                 X_test_Mm.mean(),
                                                 X_test_Mm.std()))
# Out:
# 		(min, max), (mean, std)
# Train scaled (0.00, 1.00) (0.46, 0.27)
# Train scaled (0.03, 1.06) (0.45, 0.26)

# %% [markdown]
# # 3. Max Abs Scaler

# %%
from sklearn.preprocessing import MaxAbsScaler
MaScaler = MaxAbsScaler()

MaScaler.fit(X_train)
X_train_Ma = MaScaler.transform(X_train)
X_test_Ma = MaScaler.transform(X_test)

print("\t\t(min, max), (mean, std)")
print("Train scaled (%.2f, %.2f) (%.2f, %.2f)"% (X_train_Ma.min(),
                                                 X_train_Ma.max(),
                                                 X_train_Ma.mean(),
                                                 X_train_Ma.std()))

print("Train scaled (%.2f, %.2f) (%.2f, %.2f)"% (X_test_Ma.min(),
                                                 X_test_Ma.max(),
                                                 X_test_Ma.mean(),
                                                 X_test_Ma.std()))
# Out:
# 		(min, max), (mean, std)
# Train scaled (0.04, 1.00) (0.62, 0.24)
# Train scaled (0.08, 1.03) (0.62, 0.24)

# %% [markdown]
# # 4. Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler
RuScaler = RobustScaler()

RuScaler.fit(X_train)
X_train_Ru = RuScaler.transform(X_train)
X_test_Ru = RuScaler.transform(X_test)

print("\t\t(min, max), (mean, std)")
print("Train scaled (%.2f, %.2f) (%.2f, %.2f)"% (X_train_Ru.min(),
                                                 X_train_Ru.max(),
                                                 X_train_Ru.mean(),
                                                 X_train_Ru.std()))

print("Train scaled (%.2f, %.2f) (%.2f, %.2f)"% (X_test_Ru.min(),
                                                 X_test_Ru.max(),
                                                 X_test_Ru.mean(),
                                                 X_test_Ru.std()))
# Out:
# 		(min, max), (mean, std)
# Train scaled (-1.90, 2.67) (-0.02, 0.65)
# Train scaled (-1.14, 1.90) (-0.02, 0.62)

# %% [markdown]
# # 5. 원본 스케일로 변경하기

# %%
pd.DataFrame(X_train_Ru).head(3)
# Out:
#           0         1         2         3
# 0  0.846154  0.190476  0.157143  0.133333
# 1 -0.153846 -0.380952  0.157143  0.466667
# 2 -0.076923  0.000000 -0.042857 -0.066667

# %%
X_Original = RuScaler.inverse_transform(X_train_Ru)

pd.DataFrame(X_Original).head(3)
# Out:
#      0    1    2    3
# 0  6.9  3.1  4.9  1.5
# 1  5.6  2.8  4.9  2.0
# 2  5.7  3.0  4.2  1.2
